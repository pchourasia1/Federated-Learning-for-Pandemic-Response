# %%
import numpy as np
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.decomposition import TruncatedSVD
import random
# import seaborn as sns
import os.path as path
import os
# import matplotlib
# import matplotlib.font_manager
# import matplotlib.pyplot as plt # graphs plotting
# import Bio
# from Bio import SeqIO # some BioPython that will come in handy
#matplotlib inline

from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.metrics import roc_auc_score


# from matplotlib import rc
# # for Arial typefont
# matplotlib.rcParams['font.family'] = 'Arial'

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn import svm

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

import pandas as pd
import sklearn
from sklearn import preprocessing
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler  
from sklearn.neural_network import MLPClassifier 
from sklearn.metrics import classification_report, confusion_matrix 

from sklearn.neighbors import KNeighborsClassifier

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

from pandas import DataFrame

from sklearn.model_selection import KFold 
from sklearn.model_selection import RepeatedKFold

from sklearn.metrics import confusion_matrix

from numpy import mean

# import seaborn as sns

import itertools
from itertools import product

import csv

from sklearn.model_selection import ShuffleSplit # or StratifiedShuffleSplit

from sklearn.decomposition import KernelPCA

import timeit
# from fnvhash import fnv1a_32
import matplotlib.pyplot as plt
import math

from ctypes import c_ulonglong
import ctypes

import timeit







import tensorflow as tf
from sklearn.preprocessing import LabelEncoder

def amino_acid_to_one_hot(seq):
    """Convert amino acid sequence to one-hot encoding"""
    aa_to_index = {'A': 0, 'C': 1, 'D': 2, 'E': 3, 'F': 4, 'G': 5, 'H': 6, 'I': 7, 'K': 8, 'L': 9, 'M': 10,
                   'N': 11, 'P': 12, 'Q': 13, 'R': 14, 'S': 15, 'T': 16, 'V': 17, 'W': 18, 'X': 19, 'Y': 20}

    one_hot_encoding = []
    for aa in seq:
        one_hot = [0] * len(aa_to_index)
        one_hot[aa_to_index[aa]] = 1
        one_hot_encoding.append(one_hot)
    return one_hot_encoding

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical


print("done")
# Out:
# C:\Users\pchourasia1\Anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "
# done

# %%
def roc_auc_score_multiclass(actual_class, pred_class, average = "macro"):

    unique_class = set(actual_class)
    roc_auc_dict = {}
    for per_class in unique_class:
        #creating a list of all the classes except the current class 
        other_class = [x for x in unique_class if x != per_class]

        #marking the current class as 1 and all other classes as 0
        new_actual_class = [0 if x in other_class else 1 for x in actual_class]
        new_pred_class = [0 if x in other_class else 1 for x in pred_class]

        #using the sklearn metrics method to calculate the roc_auc_score
        roc_auc = roc_auc_score(new_actual_class, new_pred_class, average = average)
        roc_auc_dict[per_class] = roc_auc
    
    
    check = pd.DataFrame(roc_auc_dict.items())
    return mean(check)

# %% [markdown]
# # Data processing

# %%
seq_data = np.load("C:/Users/pchourasia1/Desktop/FL_Workshop/data/seq_data_7000.npy",allow_pickle=True)
att_data = np.load("C:/Users/pchourasia1/Desktop/FL_Workshop/data/seq_data_variant_names_7000.npy",allow_pickle=True)
attribute_data = np.load("C:/Users/pchourasia1/Desktop/FL_Workshop/data/seq_data_all_attributes_7000.npy",allow_pickle=True)

# %%
attr_new = []
for i in range(len(att_data)):
    aa = str(att_data[i]).replace("[","")
    aa_1 = aa.replace("]","")
    aa_2 = aa_1.replace("\'","")
    attr_new.append(aa_2)

unique_hst = list(np.unique(attr_new))

int_hosts = []
for ind_unique in range(len(attr_new)):
    variant_tmp = attr_new[ind_unique]
    ind_tmp = unique_hst.index(variant_tmp)
    int_hosts.append(ind_tmp)

    
def amino_acid_to_int(seq):
    """Convert amino acid sequence to one-hot encoding"""
    aa_to_index = {'A': 0, 'C': 1, 'D': 2, 'E': 3, 'F': 4, 'G': 5, 'H': 6, 'I': 7, 'K': 8, 'L': 9, 'M': 10,
                   'N': 11, 'P': 12, 'Q': 13, 'R': 14, 'S': 15, 'T': 16, 'V': 17, 'W': 18, 'X': 19, 'Y': 20}

    one_hot_encoding = []
    for aa in seq:
#         one_hot = [0] * len(aa_to_index)
#         one_hot[aa_to_index[aa]] = 1
        one_hot_encoding.append(aa_to_index[aa])
    return one_hot_encoding

seq_int = []
for ii in range(len(seq_data)):
    seq_int.append(amino_acid_to_int(seq_data[ii]))

sequences = seq_int[:]
labels = int_hosts[:]

print("Attribute data preprocessing Done")
# Out:
# Attribute data preprocessing Done

# %%
total_amino_acids = 21
# Define number of amino acids in each protein sequence
# total_protein_sequences = 5000
# num_amino_acids = 1000
total_classes = len(np.unique(labels))

# # Generate 15 random protein sequences
# sequences = []
# for i in range(total_protein_sequences):
#     seq = [np.random.randint(1, 21) for j in range(num_amino_acids)]
#     sequences.append(seq)

# Encode the sequences into one-hot encoding
one_hot_sequences = []
for seq in sequences:
    one_hot = to_categorical(seq, num_classes=total_amino_acids)
    one_hot_sequences.append(one_hot)

# Pad the sequences to have the same length
padded_sequences = pad_sequences(one_hot_sequences, padding='post')

# # Assign class labels to the sequences
# labels = [np.random.randint(1, total_classes) for i in range(total_protein_sequences)]
encoded_labels = to_categorical(labels, num_classes=total_classes)

# %%
len(sequences[1]), labels[1], len(encoded_labels[1]), len(padded_sequences[1])
# Out:
# (1274, 6, 22, 1274)

# %%
countryList = []
variants_USA = []
variants_England = []
variants_Germany = []
variants_Denmark = []
variants_Sweden = []
variants_Japan = []
variants_Scotland = []
variants_Canada = []
variants_France = []
variants_Global = []

variantName_USA = []
variantName_England = []
variantName_Germany = []
variantName_Denmark = []
variantName_Sweden = []
variantName_Japan = []
variantName_Scotland = []
variantName_Canada = []
variantName_France = []
variantName_Global = []

seq_USA = []
seq_England = []
seq_Germany = []
seq_Denmark = []
seq_Sweden = []
seq_Japan = []
seq_Scotland = []
seq_Canada = []
seq_France = []
seq_Global = []


for i in range(len(attribute_data)):
    if attribute_data[i][5].split('/')[1] == 'USA':
        variants_USA.append(encoded_labels[i]) 
        variantName_USA.append(labels[i]) 
        seq_USA.append(padded_sequences[i]) 
    if attribute_data[i][5].split('/')[1] == 'England':
        variants_England.append(encoded_labels[i]) 
        variantName_England.append(labels[i]) 
        seq_England.append(padded_sequences[i]) 
    if attribute_data[i][5].split('/')[1] == 'Germany':
        variants_Germany.append(encoded_labels[i]) 
        variantName_Germany.append(labels[i]) 
        seq_Germany.append(padded_sequences[i]) 
    if attribute_data[i][5].split('/')[1] == 'Denmark':
        variants_Denmark.append(encoded_labels[i]) 
        variantName_Denmark.append(labels[i]) 
        seq_Denmark.append(padded_sequences[i]) 
    if attribute_data[i][5].split('/')[1] == 'Sweden':
        variants_Sweden.append(encoded_labels[i])
        variantName_Sweden.append(labels[i]) 
        seq_Sweden.append(padded_sequences[i]) 
    if attribute_data[i][5].split('/')[1] == 'Japan':
        variants_Japan.append(encoded_labels[i]) 
        variantName_Japan.append(labels[i]) 
        seq_Japan.append(padded_sequences[i]) 
    if attribute_data[i][5].split('/')[1] == 'Scotland':
        variants_Scotland.append(encoded_labels[i]) 
        variantName_Scotland.append(labels[i]) 
        seq_Scotland.append(padded_sequences[i]) 
    if attribute_data[i][5].split('/')[1] == 'Canada':
        variants_Canada.append(encoded_labels[i])  
        variantName_Canada.append(labels[i]) 
        seq_Canada.append(padded_sequences[i]) 
    if attribute_data[i][5].split('/')[1] == 'France':
        variants_France.append(encoded_labels[i])     
        variantName_France.append(labels[i]) 
        seq_France.append(padded_sequences[i]) 
    
    if attribute_data[i][5].split('/')[1] not in ('USA','England','Germany','Denmark','Sweden','Japan','Scotland','Canada', 'France'):
        variants_Global.append(encoded_labels[i])
        variantName_Global.append(labels[i]) 
        seq_Global.append(padded_sequences[i]) 
    
    countryList.append(attribute_data[i][5].split('/')[1])

# %%
np.unique(countryList), len(np.unique(countryList))
# Out:
# (array(['Albania', 'Angola', 'Argentina', 'Aruba', 'Australia', 'Austria',
#         'Bahamas', 'Bangladesh', 'Belgium', 'Benin', 'Bonaire', 'Brazil',
#         'Bulgaria', 'Cambodia', 'Canada', 'Chile', 'Colombia', 'Croatia',
#         'Curacao', 'Cyprus', 'DRC', 'Denmark', 'Ecuador', 'England',
#         'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Guadeloupe',
#         'Guatemala', 'Guinea', 'Hungary', 'Iceland', 'India', 'Indonesia',
#         'Ireland', 'Israel', 'Italy', 'Japan', 'Kenya', 'Latvia',
#         'Lebanon', 'Lithuania', 'Luxembourg', 'Malawi', 'Malaysia',
#         'Malta', 'Martinique', 'Mexico', 'Mozambique', 'Nepal',
#         'Netherlands', 'Norway', 'Pakistan', 'Philippines', 'Poland',
#         'Portugal', 'Qatar', 'Reunion', 'Romania', 'Russia', 'Scotland',
#         'Senegal', 'Singapore', 'Slovakia', 'Slovenia', 'Spain', 'Sweden',
#         'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'USA', 'Ukraine',
# ...

# %%
# pd.set_option("display.max_rows", None)
pd.Series(countryList).value_counts()
# Out:
# USA           1779
# England       1662
# Germany        470
# Denmark        374
# Sweden         241
#               ...
# Cyprus           1
# Malawi           1
# Uruguay          1
# Mozambique       1
# Zambia           1
# Length: 81, dtype: int64

# %%
len(variantName_USA), pd.Series(variantName_USA).value_counts(), len(variants_USA)
# Out:
# (1779,
#  6     636
#  10    315
#  18    178
#  2     123
#  16    106
#  17    100
#  20     76
#  15     64
#  1      58
#  12     35
#  5      28
#  3      25
#  0      18
#  14      9
#  21      6
#  8       1
#  11      1
#  dtype: int64,
#  1779)

# %%
len(variants_France), pd.Series(variantName_France).value_counts()
# Out:
# (174,
#  6     90
#  18    23
#  7     17
#  2     13
#  1     11
#  14    10
#  0      5
#  8      2
#  3      1
#  17     1
#  20     1
#  dtype: int64)

# %%
len(seq_France[1])
# Out:
# 1274

# %%
# ('USA','England','Germany','Denmark','Sweden','Japan','Scotland','Canada', 'France'):

# %%
X_train_seq_USA, X_test_seq_USA, y_train_variants_USA, y_test_variants_USA = train_test_split(seq_USA, variants_USA, test_size=0.3)
X_train_seq_England, X_test_seq_England, y_train_variants_England, y_test_variants_England = train_test_split(seq_England, variants_England, test_size=0.3)
X_train_seq_Germany, X_test_seq_Germany, y_train_variants_Germany, y_test_variants_Germany = train_test_split(seq_Germany, variants_Germany, test_size=0.3)
X_train_seq_Denmark, X_test_seq_Denmark, y_train_variants_Denmark, y_test_variants_Denmark = train_test_split(seq_Denmark, variants_Denmark, test_size=0.3)
X_train_seq_Sweden, X_test_seq_Sweden, y_train_variants_Sweden, y_test_variants_Sweden = train_test_split(seq_Sweden, variants_Sweden, test_size=0.3)
X_train_seq_Japan, X_test_seq_Japan, y_train_variants_Japan, y_test_variants_Japan = train_test_split(seq_Japan, variants_Japan, test_size=0.3)
X_train_seq_Scotland, X_test_seq_Scotland, y_train_variants_Scotland, y_test_variants_Scotland = train_test_split(seq_Scotland, variants_Scotland, test_size=0.3)
X_train_seq_Canada, X_test_seq_Canada, y_train_variants_Canada, y_test_variants_Canada = train_test_split(seq_Canada, variants_Canada, test_size=0.3)
X_train_seq_France, X_test_seq_France, y_train_variants_France, y_test_variants_France = train_test_split(seq_France, variants_France, test_size=0.3)
X_train_Global, y_train_Global = seq_Global, variants_Global

# %%
len(X_train_Global)
# Out:
# 1693

# %%
X_train_local_USA, X_train_global_USA, y_train_local_USA, y_train_global_USA = train_test_split(X_train_seq_USA, y_train_variants_USA, test_size=0.3)
X_train_local_England, X_train_global_England, y_train_local_England, y_train_global_England = train_test_split(X_train_seq_England, y_train_variants_England, test_size=0.3)
X_train_local_Germany, X_train_global_Germany, y_train_local_Germany, y_train_global_Germany = train_test_split(X_train_seq_Germany, y_train_variants_Germany, test_size=0.3)
X_train_local_Denmark, X_train_global_Denmark, y_train_local_Denmark, y_train_global_Denmark = train_test_split(X_train_seq_Denmark, y_train_variants_Denmark, test_size=0.3)
X_train_local_Sweden, X_train_global_Sweden, y_train_local_Sweden, y_train_global_Sweden = train_test_split(X_train_seq_Sweden, y_train_variants_Sweden, test_size=0.3)
X_train_local_Japan, X_train_global_Japan, y_train_local_Japan, y_train_global_Japan = train_test_split(X_train_seq_Japan, y_train_variants_Japan, test_size=0.3)
X_train_local_Scotland, X_train_global_Scotland, y_train_local_Scotland, y_train_global_Scotland = train_test_split(X_train_seq_Scotland, y_train_variants_Scotland, test_size=0.3)
X_train_local_Canada, X_train_global_Canada, y_train_local_Canada, y_train_global_Canada = train_test_split(X_train_seq_Canada, y_train_variants_Canada, test_size=0.3)
X_train_local_France, X_train_global_France, y_train_local_France, y_train_global_France = train_test_split(X_train_seq_France, y_train_variants_France, test_size=0.3)

# %%
len(X_train_global_USA), len(X_train_global_England), len(X_train_global_Germany), len(X_train_global_Denmark), len(X_train_global_Sweden), len(X_train_global_Japan), len(X_train_global_Scotland), len(X_train_global_Canada), len(X_train_global_France)
# Out:
# (374, 349, 99, 79, 51, 47, 41, 40, 37)

# %%
len(y_train_global_USA), len(y_train_global_England), len(y_train_global_Germany), len(y_train_global_Denmark), len(y_train_global_Sweden), len(y_train_global_Japan), len(y_train_global_Scotland), len(y_train_global_Canada), len(y_train_global_France)
# Out:
# (374, 349, 99, 79, 51, 47, 41, 40, 37)

# %%
X_train_Global = X_train_Global + X_train_global_USA
X_train_Global = X_train_Global + X_train_global_England
X_train_Global = X_train_Global + X_train_global_Germany
X_train_Global = X_train_Global + X_train_global_Denmark
X_train_Global = X_train_Global + X_train_global_Sweden
X_train_Global = X_train_Global + X_train_global_Japan
X_train_Global = X_train_Global + X_train_global_Scotland
X_train_Global = X_train_Global + X_train_global_Canada
X_train_Global = X_train_Global + X_train_global_France

# %%
len(X_train_Global)
# Out:
# 2810

# %%
len(y_train_Global)
# Out:
# 1693

# %%
len(y_train_global_USA) + len(y_train_global_England) + len(y_train_global_Germany) + len(y_train_global_Denmark) + len(y_train_global_Sweden) + len(y_train_global_Japan) + len(y_train_global_Scotland) + len(y_train_global_Canada) + len(y_train_global_France)
# Out:
# 1117

# %%
y_train_Global = y_train_Global + y_train_global_USA
y_train_Global = y_train_Global + y_train_global_England
y_train_Global = y_train_Global + y_train_global_Germany
y_train_Global = y_train_Global + y_train_global_Denmark
y_train_Global = y_train_Global + y_train_global_Sweden
y_train_Global = y_train_Global + y_train_global_Japan
y_train_Global = y_train_Global + y_train_global_Scotland
y_train_Global = y_train_Global + y_train_global_Canada
y_train_Global = y_train_Global + y_train_global_France

# %%
len(y_train_Global), type(X_train_global_USA)
# Out:
# (2810, list)

# %%
y_train_Global = np.asarray(y_train_Global) 
X_train_Global = np.asarray(X_train_Global)

# %%
X_train_Global.shape,len(sequences[0])
# Out:
# ((2810, 1274, 21), 1274)

# %%
# # Split the sequences into training and testing set
# X_train_1, X_test, y_train_1, y_test = train_test_split(padded_sequences, encoded_labels, test_size=0.3)

# # Split the sequences into training 1 and training 2 set
# X_train_local, X_train_global, y_train_local, y_train_global = train_test_split(X_train_1, y_train_1, test_size=0.3)

# %%
X_train_Global.shape, type(X_train_Global), y_train_Global.shape, type(y_train_Global)
# Out:
# ((2810, 1274, 21), numpy.ndarray, (2810, 22), numpy.ndarray)

# %%
X_train_local_USA = np.asarray(X_train_local_USA)
X_train_local_England = np.asarray(X_train_local_England)
X_train_local_Germany = np.asarray(X_train_local_Germany)
X_train_local_Denmark = np.asarray(X_train_local_Denmark)
X_train_local_Sweden = np.asarray(X_train_local_Sweden)
X_train_local_Japan = np.asarray(X_train_local_Japan)
X_train_local_Scotland = np.asarray(X_train_local_Scotland)
X_train_local_Canada = np.asarray(X_train_local_Canada)
X_train_local_France = np.asarray(X_train_local_France)

# %%
y_train_local_USA = np.asarray(y_train_local_USA)
y_train_local_England  = np.asarray(y_train_local_England)
y_train_local_Germany  = np.asarray(y_train_local_Germany)
y_train_local_Denmark  = np.asarray(y_train_local_Denmark)
y_train_local_Sweden   = np.asarray(y_train_local_Sweden)
y_train_local_Japan    = np.asarray(y_train_local_Japan)
y_train_local_Scotland = np.asarray(y_train_local_Scotland)
y_train_local_Canada   = np.asarray(y_train_local_Canada)
y_train_local_France   = np.asarray(y_train_local_France)

# %%
X_train_local_USA.shape, type(X_train_local_USA), y_train_local_USA.shape, type(y_train_local_USA)
# Out:
# ((871, 1274, 21), numpy.ndarray, (871, 22), numpy.ndarray)

# %%
X_test = X_test_seq_USA + X_test_seq_England  + X_test_seq_Germany  + X_test_seq_Denmark  + X_test_seq_Sweden   + X_test_seq_Japan    + X_test_seq_Scotland + X_test_seq_Canada   + X_test_seq_France  
y_test = y_test_variants_USA + y_test_variants_England  + y_test_variants_Germany  + y_test_variants_Denmark  + y_test_variants_Sweden   + y_test_variants_Japan    + y_test_variants_Scotland + y_test_variants_Canada   + y_test_variants_France

# %%
X_test = np.asarray(X_test)
y_test = np.asarray(y_test)

# %% [markdown]
# # Save Files

# %%
# np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/y_train_local_USA.npy", y_train_local_USA)
# np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/y_train_local_England.npy", y_train_local_England)
# np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/y_train_local_Germany.npy", y_train_local_Germany)

np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/y_train_local_Denmark.npy", y_train_local_Denmark)
np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/y_train_local_Sweden.npy", y_train_local_Sweden)
np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/y_train_local_Japan.npy", y_train_local_Japan)
np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/y_train_local_Scotland.npy", y_train_local_Scotland)
np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/y_train_local_Canada.npy", y_train_local_Canada)
np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/y_train_local_France.npy", y_train_local_France)

# %%
np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/X_train_local_USA.npy", X_train_local_USA)
np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/X_train_local_England.npy", X_train_local_England)
np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/X_train_local_Germany.npy", X_train_local_Germany)
np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/X_train_local_Denmark.npy", X_train_local_Denmark)
np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/X_train_local_Sweden.npy", X_train_local_Sweden)
np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/X_train_local_Japan.npy", X_train_local_Japan)
np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/X_train_local_Scotland.npy", X_train_local_Scotland)
np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/X_train_local_Canada.npy", X_train_local_Canada)
np.save("C:/Users/pchourasia1/Desktop/FL_Workshop/OHE_Vectors_And_Labels/X_train_local_France.npy", X_train_local_France)

# %% [markdown]
# # Load Data / Continue for your set

# %%
train_parts = [] 
label_parts = []

train_parts.append(X_train_local_USA)
train_parts.append(X_train_local_England)
train_parts.append(X_train_local_Germany)
train_parts.append(X_train_local_Denmark)
train_parts.append(X_train_local_Sweden)
train_parts.append(X_train_local_Japan)
train_parts.append(X_train_local_Scotland)
train_parts.append(X_train_local_Canada)
train_parts.append(X_train_local_France)

label_parts.append(y_train_local_USA)
label_parts.append(y_train_local_England)
label_parts.append(y_train_local_Germany)
label_parts.append(y_train_local_Denmark)
label_parts.append(y_train_local_Sweden)
label_parts.append(y_train_local_Japan)
label_parts.append(y_train_local_Scotland)
label_parts.append(y_train_local_Canada)
label_parts.append(y_train_local_France)

# %%
len(train_parts) , type(train_parts), type(label_parts)
# Out:
# (9, list, list)

# %%
total_epoch = 100

total_Local_Models = 9

start = timeit.default_timer() 

# Define local models
local_models = []
for i in range(total_Local_Models):
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(len(sequences[0]), total_amino_acids)),
        tf.keras.layers.Dense(512, activation='tanh',activity_regularizer=tf.keras.regularizers.l1(0.01)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(256, activation='tanh',activity_regularizer=tf.keras.regularizers.l1(0.01)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='tanh',activity_regularizer=tf.keras.regularizers.l1(0.01)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(64, activation='tanh',activity_regularizer=tf.keras.regularizers.l1(0.01)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(32, activation='tanh',activity_regularizer=tf.keras.regularizers.l1(0.01)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
#         tf.keras.layers.Dense(16, activation='relu'),
#         tf.keras.layers.Dense(8, activation='relu'),
        tf.keras.layers.Dense(total_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    local_models.append(model)

history = []
# Train local models
for i, (part, labels_part) in enumerate(zip(train_parts, label_parts)):
    history.append(local_models[i].fit(part, labels_part, epochs=total_epoch))

print(history[1].history.keys())  
    
#Define the global model
global_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(len(sequences[0]), total_amino_acids)),
    tf.keras.layers.Dense(512, activation='tanh',activity_regularizer=tf.keras.regularizers.l1(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(256, activation='tanh',activity_regularizer=tf.keras.regularizers.l1(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(128, activation='tanh',activity_regularizer=tf.keras.regularizers.l1(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='tanh',activity_regularizer=tf.keras.regularizers.l1(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(32, activation='tanh',activity_regularizer=tf.keras.regularizers.l1(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
#     tf.keras.layers.Dense(16, activation='relu'),
#     tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(total_classes, activation='softmax')
    ])

#Compile the global model
global_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

#Initialize the global model with weights from local models
weights = []
for local_model in local_models:
    weights.append(local_model.get_weights())

# Take Max Min and Mean - 3 Models 

average_weights = []
for i in range(len(weights[0])):
    layer_weights = np.mean([w[i] for w in weights], axis=0)
    average_weights.append(layer_weights)

global_model.set_weights(average_weights)


global_history=[]
#Train the global model
global_history = global_model.fit(X_train_Global, y_train_Global, epochs=total_epoch)

#Evaluate the global model on test data
test_loss, test_accuracy = global_model.evaluate(X_test, y_test)

stop = timeit.default_timer()
print("Total Time : ", stop - start) 

print("Test Loss: ", test_loss)
print("Test Accuracy: ", test_accuracy)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 11s 156ms/step - loss: 11.5301 - accuracy: 0.1125
# Epoch 2/100
# 28/28 [==============================] - 4s 160ms/step - loss: 11.2020 - accuracy: 0.2710
# Epoch 3/100
# 28/28 [==============================] - 4s 160ms/step - loss: 10.7782 - accuracy: 0.4007
# Epoch 4/100
# 28/28 [==============================] - 4s 160ms/step - loss: 10.5315 - accuracy: 0.4684
# Epoch 5/100
# 28/28 [==============================] - 5s 162ms/step - loss: 10.3825 - accuracy: 0.4868
# Epoch 6/100
# 28/28 [==============================] - 4s 160ms/step - loss: 10.2868 - accuracy: 0.5189
# Epoch 7/100
# 28/28 [==============================] - 4s 150ms/step - loss: 10.2345 - accuracy: 0.5281
# Epoch 8/100
# 28/28 [==============================] - 4s 154ms/step - loss: 10.1383 - accuracy: 0.5396
# Epoch 9/100
# 28/28 [==============================] - 4s 155ms/step - loss: 10.1238 - accuracy: 0.5327
# Epoch 10/100
# ...

# %%
print(global_history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
global_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_9 (Flatten)         (None, 26754)             0
#
#  dense_54 (Dense)            (None, 512)               13698560
#
#  batch_normalization_45 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_45 (Dropout)        (None, 512)               0
#
#  dense_55 (Dense)            (None, 256)               131328
#
#  batch_normalization_46 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_46 (Dropout)        (None, 256)               0
#
#  dense_56 (Dense)            (None, 128)               32896
#
#  batch_normalization_47 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_47 (Dropout)        (None, 128)               0
#
#  dense_57 (Dense)            (None, 64)                8256
#
#  batch_normalization_48 (Bat  (None, 64)               256
#  chNormalization)
#
# ...

# %%
# local_models[5].summary()

# %%
len(local_models),i,len(train_parts)
# Out:
# (9, 31, 9)

# %% [markdown]
# ## Save Loss and Accuracy

# %%
d = {'accuracy':global_history.history['accuracy'] ,'loss':global_history.history['loss']}
df = pd.DataFrame(d)
df.index = np.arange(1, len(df) + 1)

# %%
df.to_csv("C:/Users/pchourasia1/Desktop/FL_Workshop/results/global_loss_accuracy.csv")

# %%
d = {'accuracy':history[0].history['accuracy'] ,'loss':history[0].history['loss']}
df = pd.DataFrame(d)
df.index = np.arange(1, len(df) + 1)

# %%
df.to_csv("C:/Users/pchourasia1/Desktop/FL_Workshop/results/Local_USA_loss_accuracy.csv")

# %%
d = {'accuracy':history[1].history['accuracy'] ,'loss':history[1].history['loss']}
df = pd.DataFrame(d)
df.index = np.arange(1, len(df) + 1)

# %%
df.to_csv("C:/Users/pchourasia1/Desktop/FL_Workshop/results/Local_England_loss_accuracy.csv")

# %%
d = {'accuracy':history[2].history['accuracy'] ,'loss':history[2].history['loss']}
df = pd.DataFrame(d)
df.index = np.arange(1, len(df) + 1)

# %%
df.to_csv("C:/Users/pchourasia1/Desktop/FL_Workshop/results/Local_Germany_loss_accuracy.csv")

# %%
d = {'accuracy':history[3].history['accuracy'] ,'loss':history[3].history['loss']}
df = pd.DataFrame(d)
df.index = np.arange(1, len(df) + 1)

# %%
df.to_csv("C:/Users/pchourasia1/Desktop/FL_Workshop/results/Local_Denmark_loss_accuracy.csv")

# %%
d = {'accuracy':history[4].history['accuracy'] ,'loss':history[4].history['loss']}
df = pd.DataFrame(d)
df.index = np.arange(1, len(df) + 1)

# %%
df.to_csv("C:/Users/pchourasia1/Desktop/FL_Workshop/results/Local_Sweden_loss_accuracy.csv")

# %%
d = {'accuracy':history[5].history['accuracy'] ,'loss':history[5].history['loss']}
df = pd.DataFrame(d)
df.index = np.arange(1, len(df) + 1)

# %%
df.to_csv("C:/Users/pchourasia1/Desktop/FL_Workshop/results/Local_Japan_loss_accuracy.csv")

# %%
d = {'accuracy':history[6].history['accuracy'] ,'loss':history[6].history['loss']}
df = pd.DataFrame(d)
df.index = np.arange(1, len(df) + 1)

# %%
df.to_csv("C:/Users/pchourasia1/Desktop/FL_Workshop/results/Local_Scotland_loss_accuracy.csv")

# %%
d = {'accuracy':history[7].history['accuracy'] ,'loss':history[7].history['loss']}
df = pd.DataFrame(d)
df.index = np.arange(1, len(df) + 1)

# %%
df.to_csv("C:/Users/pchourasia1/Desktop/FL_Workshop/results/Local_Canada_loss_accuracy.csv")

# %%
d = {'accuracy':history[8].history['accuracy'] ,'loss':history[8].history['loss']}
df = pd.DataFrame(d)
df.index = np.arange(1, len(df) + 1)

# %%
df.to_csv("C:/Users/pchourasia1/Desktop/FL_Workshop/results/Local_France_loss_accuracy.csv")

# %% [markdown]
# ## Metrics

# %%
type(global_history.history['loss'])
# Out:
# list

# %%
print(history[1].history['loss'])
# Out:
# [11.284570693969727, 10.695293426513672, 10.054683685302734, 9.8897705078125, 9.563863754272461, 9.562166213989258, 9.449162483215332, 9.449973106384277, 9.393756866455078, 9.375710487365723, 9.313841819763184, 9.242136001586914, 9.229325294494629, 9.22287368774414, 9.246411323547363, 9.241100311279297, 9.274246215820312, 9.202005386352539, 9.169193267822266, 9.153173446655273, 9.207193374633789, 9.12864875793457, 9.110450744628906, 9.110982894897461, 9.000448226928711, 9.09986400604248, 9.084665298461914, 9.045543670654297, 9.027260780334473, 8.994497299194336, 8.976343154907227, 8.938121795654297, 8.941849708557129, 8.979975700378418, 8.868030548095703, 8.869708061218262, 8.863204002380371, 8.800830841064453, 8.813190460205078, 8.844135284423828, 8.79427433013916, 8.833685874938965, 8.7415771484375, 8.717680931091309, 8.692978858947754, 8.659457206726074, 8.752888679504395, 8.700742721557617, 8.668282508850098, 8.628910064697266, 8.591837882995605, 8.529780387878418, 8.592428207397
# ...

# %%
print(global_history.history['accuracy'])
# Out:
# [0.5448398590087891, 0.591103196144104, 0.5964412689208984, 0.6000000238418579, 0.5960854291915894, 0.5896797180175781, 0.5918149352073669, 0.5921708345413208, 0.5900355577468872, 0.5939501523971558, 0.5950177907943726, 0.5832740068435669, 0.5875445008277893, 0.5932384133338928, 0.5864768624305725, 0.5918149352073669, 0.5889679789543152, 0.5928825736045837, 0.5957295298576355, 0.5868327617645264, 0.5889679789543152, 0.5839857459068298, 0.5960854291915894, 0.591103196144104, 0.5946619510650635, 0.599288284778595, 0.600355863571167, 0.5882562398910522, 0.599288284778595, 0.5975089073181152, 0.591103196144104, 0.5960854291915894, 0.6024910807609558, 0.5978647470474243, 0.5985764861106873, 0.6053380966186523, 0.5971530079841614, 0.599644124507904, 0.6046263575553894, 0.5982206463813782, 0.6106761693954468, 0.6021352410316467, 0.6074733138084412, 0.5985764861106873, 0.6071174144744873, 0.6138790249824524, 0.6046263575553894, 0.6056939363479614, 0.5967971682548523, 0.5939501523971558, 0.59
# ...

# %%
print(history[1].history['accuracy'])
# Out:
# [0.12407862395048141, 0.37960687279701233, 0.5823096036911011, 0.6093366146087646, 0.6830466985702515, 0.6597051620483398, 0.7063882350921631, 0.7002456784248352, 0.6891891956329346, 0.6953316926956177, 0.7051597237586975, 0.7162162065505981, 0.687960684299469, 0.7088451981544495, 0.7051597237586975, 0.7027027010917664, 0.684275209903717, 0.7211301922798157, 0.7002456784248352, 0.7014741897583008, 0.6977887153625488, 0.7088451981544495, 0.7137592434883118, 0.7223587036132812, 0.7211301922798157, 0.7039312124252319, 0.7223587036132812, 0.6953316926956177, 0.7211301922798157, 0.7186732292175293, 0.7039312124252319, 0.7235872149467468, 0.7223587036132812, 0.7051597237586975, 0.735872209072113, 0.710073709487915, 0.7149876952171326, 0.7063882350921631, 0.710073709487915, 0.7088451981544495, 0.7186732292175293, 0.7113022208213806, 0.735872209072113, 0.7162162065505981, 0.7063882350921631, 0.7248157262802124, 0.7014741897583008, 0.7125307321548462, 0.7321867346763611, 0.7272727489471436, 0
# ...

# %%
from sklearn.metrics import precision_recall_fscore_support, roc_auc_score
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import f1_score

# Make predictions on test set using the global model
y_pred_global = global_model.predict(X_test)
y_pred_global = np.argmax(y_pred_global, axis=1)
y_test_original = np.argmax(y_test, axis=1)

# Compute precision, recall, F1, and support for each class
precision, recall, f1, support = precision_recall_fscore_support(y_test_original, y_pred_global, average='weighted')
print("Weighted precision: ", precision)
print("Weighted recall: ", recall)
print("Weighted F1: ", f1)

# Compute macro F1
lb = LabelBinarizer()
lb.fit(y_test_original)
y_test_binarized = lb.transform(y_test_original)
y_pred_global_binarized = lb.transform(y_pred_global)
macro_f1 = f1_score(y_test_binarized, y_pred_global_binarized, average='macro')
print("Macro F1: ", macro_f1)

# Compute ROC-AUC
roc_auc = roc_auc_score_multiclass(y_test_original, y_pred_global, average='macro')
print("ROC-AUC: ", roc_auc[1])
# Out:
# 50/50 [==============================] - 1s 10ms/step
# Weighted precision:  0.538970090115103
# Weighted recall:  0.6361928616155291
# Weighted F1:  0.5716211451849396
# Macro F1:  0.136329352770105
# ROC-AUC:  0.5819354049513874
# C:\Users\pchourasia1\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
np.unique(y_pred_global)
# Out:
# array([ 2,  6, 14, 18, 20], dtype=int64)
